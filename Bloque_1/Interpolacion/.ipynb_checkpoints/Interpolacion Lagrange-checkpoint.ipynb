# %% [markdown]
# # Interpolación de Lagrange

# %%
import numpy as np
import matplotlib.pyplot as plt

def bary_interpol(puntosx, puntosy, x):
    n = puntosx.size
    pesos = np.ones_like(puntosx)
    for i in range(n):
        for j in range(n):
            if j != i:
                pesos[i] *= (puntosx[i]-puntosx[j])
    pesos = 1/pesos
    if not np.any(puntosx == x):
        numerador = np.sum(pesos*puntosy/(x-puntosx))
        denominador = np.sum(pesos/(x-puntosx))
        predic = numerador/denominador
    else:
        k = np.where(x == puntosx)[0]
        predic = puntosy[k[0]]
        
    return predic

# %%
#Range función
func = lambda x: 1/(1+25*x**2)

#Generando datos ficticios
def generatedata(n, f, nodes="cheb"):
    if nodes=="cheb":
        puntosx = -np.cos(np.linspace(0,np.pi,n))
    else:
        puntosx = np.linspace(-1,1,n) 
    
    puntosy = f(puntosx)
    return puntosx, puntosy

puntosx, puntosy = generatedata(15, func)
#pesos = wsubk(puntosx)
x = 0.3
pofx = bary_interpol(puntosx, puntosy, x)

print(x, pofx, func(x))

puntosx, puntosy = generatedata(30, func)

pofx = bary_interpol(puntosx, puntosy, x)

print(x, pofx, func(x))
# Out:
# 0.3 0.2592750581841138 0.3076923076923077
# 0.3 0.30919782568113174 0.3076923076923077

# %%
pof1x = lambda x, puntosx, puntosy: bary_interpol(puntosx, puntosy, x)
x_values = np.linspace(-1, 1, 100)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].plot(x_values, func(x_values), 'k--', label='Función original')
axes[1].plot(x_values, func(x_values), 'k--', label='Función original')

puntosx_15, puntosy_15 = generatedata(15, func)
daty_15 = np.array([pof1x(i, puntosx_15, puntosy_15) for i in x_values])
axes[0].plot(puntosx_15, puntosy_15, 'ko', label='Datos (15 puntos)')
axes[0].plot(x_values, daty_15, c='b', label='Interpolación (15 puntos)')

puntosx_25, puntosy_25 = generatedata(250, func)
daty_25 = np.array([pof1x(i, puntosx_25, puntosy_25) for i in x_values])
axes[1].plot(puntosx_25, puntosy_25, 'ko', label='Datos (25 puntos)')
axes[1].plot(x_values, daty_25, c='r', label='Interpolación (25 puntos)')

axes[0].set_title('Interpolación con 15 datos')
axes[0].legend()
axes[0].grid(True)

axes[1].set_title('Interpolación con 25 datos')
axes[1].legend()
axes[1].grid(True)

# %%
0.3 0.2592750581841138 0.3076923076923077
0.3 0.3091978256811317 0.3076923076923077

#def wsubk(puntosx):
   # n = puntosx.size
    #pesos = np.ones_like(puntosx)
   # for k in range(n):
  #      for j in range(n):
   #         if j != k:
        #        pesos[k] *= (puntosx[k]-puntosx[j])
    #pesos = 1/pesos
